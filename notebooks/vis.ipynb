# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
sys.path.append("/home/local/VANDERBILT/litz/github/MASILab/thoraxtools/func")
from vis import vis

# %%
train_dir = "/home/litz/data/vlsp/npy/train"
label_dir = "/home/litz/data/vlsp/npy/label"
fname = "00000676time20170602.npy"

img = np.load(os.path.join(train_dir, fname))[0]
label = np.load(os.path.join(label_dir, fname))[0]

# %%
xyz = (150,150,150)
vis.vis_overlay_slices(img, label, xyz, clip_range=[0,1])
